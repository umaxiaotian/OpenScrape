# %% [markdown]
# # OpenScrapeライブラリをインストールします。

# %%
# !pip install git+https://github.com/umaxiaotian/OpenScrape.git@main
# Out:
# ...
#   Cloning https://github.com/umaxiaotian/OpenScrape.git (to revision main) to /tmp/pip-req-build-zmopvviv
#   Running command git clone --filter=blob:none --quiet https://github.com/umaxiaotian/OpenScrape.git /tmp/pip-req-build-zmopvviv
#   Resolved https://github.com/umaxiaotian/OpenScrape.git to commit 7c7becc88df0502dd5745516a8bf023bd6e998e3
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install pandas

# %% [markdown]
# # 取得して表形式にする。

# %%
from OpenScrape import google
import pandas as pd

#トップ10までを取得
result = google.search(search="Qiita",num_results=5,lang="ja",sleep_interval=3,timeout=5)
result
# Out:
# [{'title': 'Qiita',
#   'link': 'https://qiita.com/',
#   'description': 'Qiitaは、エンジニアに関する知識を記録・共有するためのサービスです。 プログラミングに関するTips、ノウハウ、メモを簡単に記録 & 公開することができます。'},
#  {'title': 'Qiita',
#   'link': 'https://qiita.com/',
#   'description': 'Qiitaは、エンジニアに関する知識を記録・共有するためのサービスです。 プログラミングに関するTips、ノウハウ、メモを簡単に記録 & 公開することができます。'},
#  {'title': 'Qiita',
#   'link': 'https://qiita.ucsd.edu/',
#   'description': 'Qiita (canonically pronounced cheetah) is an entirely open-source microbial study management platform. It allows users to keep track of multiple studies\xa0...'},
#  {'title': 'qiita-spots/qiita: Qiita - A multi-omics databasing effort',
#   'link': 'https://github.com/qiita-spots/qiita',
#   'description': "Qiita's main site provides database and compute resources to the global community, alleviating the technical burdens, such as familiarity with the command line\xa0..."},
#  {'title': "Welcome to Qiita's documentation!",
#   'link': 'https://qiita.ucsd.edu/static/doc/html/index.html',
# ...

# %%
# データをpandas DataFrameに変換
df = pd.DataFrame(result)

# DataFrameを表示
df
# Out:
#                                                title  \
# 0                                              Qiita
# 1                                              Qiita
# 2                                              Qiita
# 3  qiita-spots/qiita: Qiita - A multi-omics datab...
# 4                  Welcome to Qiita's documentation!
#
#                                                 link  \
# 0                                 https://qiita.com/
# 1                                 https://qiita.com/
# 2                            https://qiita.ucsd.edu/
# 3               https://github.com/qiita-spots/qiita
# 4  https://qiita.ucsd.edu/static/doc/html/index.html
#
#                                          description
# 0  Qiitaは、エンジニアに関する知識を記録・共有するためのサービスです。 プログラミングに関...
# 1  Qiitaは、エンジニアに関する知識を記録・共有するためのサービスです。 プログラミングに関...
# 2  Qiita (canonically pronounced cheetah) is an e...
# 3  Qiita's main site provides database and comput...
# 4  Qiita (canonically pronounced cheetah) is a so...
